# %% [markdown]
# # 현실적으로 내가 할수있는건
# (배열, 해시맵, 기본 문자열 처리, 반복문/조건문, 정렬, 기본 스택/큐 활용, 간단한 그리디)
# 이정도 뿐이야.
# 구현, 시뮬레이션 문제를 푼다ㄹ
#
# ```
# 민석님은 그냥 구현문제 많이 풀라는데?
# 문제에서 자연어로 적혀있는대로 코드로 구현할수있는가? 이게 회사에서 원하는거 같다고 했어
# ```
#
#
# - [x] 프로그래머스 - 숫자 문자열과 영단어(Level 1)
# - [x] 프로그래머스 - 시저 암호(Level 1)
# - [x] 프로그래머스 - 같은 숫자는 싫어 (Level 1)
# - [x]백준 2980번 - 도로와 신호등 (Silver IV)
# - [x] 프로그레머스 - 실패율
# - [xs] 프로그래머스 - 비밀지도

# %% [markdown]
# 6일 뒤 인턴 코테: 한시간
# 내 플랜:
# 1단계: 배열, 해시맵, 기본 문자열 처리, 반복문/조건문
# 2단계:  정렬, 기본 스택/큐 활용, 간단한 그리디
# 3단계: 구현문제
# 횟수: 하루 각 한번씩
# 수준: 백준 실버, 프로그래머스 레벨1~2단계문제

# %% [markdown]
# 오늘 할일 -> 5일 남았다
# 현실적으로 내가 할수있는건
# 1단계(필수): 배열, 해시맵, 기본 문자열 처리, 반복문/조건문
# 2단계(중요): 정렬, 기본 스택/큐 활용, 간단한 그리디
# 이정도 뿐이야
#
#
# 3단계(선택): 이진 탐색, BFS/DFS, 동적 프로그래밍 기초?
# 이거 못해
#
# 저거 매일 풀면서 하고 구현문제같이 풀어야해
#
# 백준, 프로그레머스에서 한문제 씩 받아서 푼다
#
# - [x] 프로그래머스 - 주차 요금 계산 # 너무 어려워서 못품
# - [x] 프로그레머스 - 최소 직사각형
#
#
# -----
# 다음은 오늘 현실적으로 풀 수 있고, 핵심 개념을 잘 배울 수 있는 문제들입니다:
# 1. 배열/구현
# - [x] 프로그래머스 - 키패드 누르기 (Level 1)
#
# 개념: 2차원 배열, 조건문, 구현
# 요약: 스마트폰 키패드에서 왼손과 오른손의 위치를 추적하며 키패드를 누르는 손가락 결정
# 학습 포인트: 2차원 좌표 처리, 맨해튼 거리 계산
#
# 2. 해시맵
# - [x] 프로그래머스 - 완주하지 못한 선수 (Level 1)
#
# 개념: 해시맵
# 요약: 참가자 명단과 완주자 명단을 비교해 완주하지 못한 선수 찾기
# 학습 포인트: 해시맵을 활용한 검색 최적화
#
# 3. 문자열 처리
# - [x] 프로그래머스 - 숫자 문자열과 영단어 (Level 1)
#
# 개념: 문자열 파싱, 치환
# 요약: 영단어로 된 숫자를 실제 숫자로 변환
# 학습 포인트: 문자열 매핑과 치환
#
# 4. 정렬
# - [x]프로그래머스 - K번째수 (Level 1)
#
# 개념: 배열 조작, 정렬
# 요약: 배열의 특정 구간을 잘라서 정렬 후 K번째 값 찾기
# 학습 포인트: 부분 배열 추출과 정렬
#
# 5. 스택/큐
# - [x] 프로그래머스 - 같은 숫자는 싫어 (Level 1)
#
# 개념: 스택 활용
# 요약: 연속된 중복 숫자 제거
# 학습 포인트: 스택을 이용한 중복 원소 필터링
#
# 6. 그리디
# - [x] 프로그래머스 - 체육복 (Level 1)
#
# 개념: 그리디 알고리즘
# 요약: 체육복을 도난당한 학생과 여벌이 있는 학생을 고려해 최대한 많은 학생이 체육복을 가지도록 함
# 학습 포인트: 최적해를 위한 그리디 선택
#
# 7. 시뮬레이션
# - []백준 2980번 - 도로와 신호등 (Silver IV)
#
# 개념: 시뮬레이션
# 요약: 주어진 도로에서 신호등마다 대기 시간을 고려하여 총 이동 시간 계산
# 학습 포인트: 시간에 따른 상태 변화 추적

# %% [markdown]
# - [x] 프로그래머스 - 주차 요금 계산

# %%
# 문제: 차량별 주차 시간을 계산하고 요금표에 따라 주차 요금을 계산
# 차량번호를 키로하는 딕셔너리 구현 
def solution(fees, records):
    answer = []
    return answer

# 다른 사람 해답 (클래스 써서 구체화)
# from collections import defaultdict
# from math import ceil

# class Parking:
#     def __init__(self, fees):
#         self.fees = fees
#         self.in_flag = False
#         self.in_time = 0
#         self.total = 0

#     def update(self, t, inout):
#         self.in_flag = True if inout=='IN' else False
#         if self.in_flag:  self.in_time = str2int(t)
#         else:             self.total  += (str2int(t)-self.in_time)

#     def calc_fee(self):
#         if self.in_flag: self.update('23:59', 'out')
#         add_t = self.total - self.fees[0]
#         return self.fees[1] + ceil(add_t/self.fees[2]) * self.fees[3] if add_t >= 0 else self.fees[1]

# def str2int(string):
#     return int(string[:2])*60 + int(string[3:])

# def solution(fees, records):
#     recordsDict = defaultdict(lambda:Parking(fees))
#     for rcd in records:
#         t, car, inout = rcd.split()
#         recordsDict[car].update(t, inout)
#     return [v.calc_fee() for k, v in sorted(recordsDict.items())]

# %% [markdown]
# - [ ] 프로그레머스 - 최소 직사각형

# %%
# 난 이렇게 했는데 이거 아니래

# def solution(sizes):
    
#     max_column = []
#     max_row = []
#     for idx in sizes:
#         if max_column < idx[0]:
#             max_column = idx

#         if max_row < idx[1]:
#             max_row = idx[1]

#     max_value = your_array[max_row][max_column]

#     answer = 0
#     return answer


def solution(size):
    max_width = 0
    max_height = 0

    for card in size:

        width = max(card[0], card[1])
        height = min(card[0], card[1])

        max_wigth = max(max_width, width)
        max_height = max(max_height, height)

    answer = max_wigth * max_height
    return answer

# 다른분 코드 
def solution(sizes):
    row = 0 # 열
    col = 0 # 행 초기값 설정
    # 항상 가로가 크게 만들어주고 
    for a, b  in sizes:
        if a < b: 
            a, b = b, a
        row = max(row, a)
        col = max(col, b)
    
    return row * col

# %% [markdown]
# - [x] 프로그래머스 - 키패드 누르기 (Level 1)

# %%
def solution(numbers, hand):
    right = "#"
    left = "*"
    keypad = {
        1: (0, 0), 2: (0, 1), 3: (0, 2),
        4: (1, 0), 5: (1, 1), 6: (1, 2),
        7: (2, 0), 8: (3, 1), 9: (2, 2),
        "*": (3, 0), 0: (3, 1), "#": (3, 2)
    }
    answer = ""
    def get_distance(pos1, pos2):
        return abs(pos1[0] - pos2[0]) + abs(pos1[1] - pos2[1]) # abs() 함수 : 절대값을 반환하는 내장함수
    
    for num in numbers:
        if num == 1 or num == 4 or num == 7:
            result = "L"
            left = num
            answer += result
        elif num == 3 or num == 6 or num == 9:
            result = "R"
            right = num
            answer += result
        else:
            left_dist = get_distance(keypad[left], keypad[num])
            right_dist = get_distance(keypad[right], keypad[num])

        if left_dist < right_dist:
            result = "L"
            left = num
        elif right_dist < left_dist:
            result = "R"
            right = num
        else:
            if hand == "left":
                result = "L"
                left = num
            else:
                result = "R"
                left = num
        answer += result

    return answer

# %% [markdown]
# - [x] 프로그래머스 - 숫자 문자열과 영단어(Level 1)

# %%
# 이렇게 했는데 숫자를 글자로 바꾸는게 아니라 글자를 숫자로 바꾸는거였음
# 쭈밤 다시한다


# def solution(s):
#     result = ""

#     # for i in range(s):# range는 정수만 인덱스접근방식
#     for word in s:
#         if word.isdigit():
#             if word == '1':
#                 result += "one"
#             elif word == '2':
#                 result += "two"
#             elif word == '3':
#                 result += "three"
#             elif word == '4':
#                 result += "four"
#             elif word == '5':
#                 result += "five"
#             elif word == '6':
#                 result += "six"
#             elif word == '7':
#                 result += "seven"
#             elif word == '8':
#                 result += "eight"
#             elif word == '9':
#                 result += "nine"
#         else:
#             result += word
        
#     return result


# 다른사람 풀이
def solution(s):
    words = ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

    for i in range(len(words)):
        s = s.replace(words[i], str(i))

    return int(s)

# %%
# - [x] 프로그래머스 - 시저 암호(Level 1)
    # s: 문자열, n: 거리
    # s를 n 만큼 민 암호문을 만들어라
def solution(s, n):
    
    if 
    
    result = ""
    char = ["a"]

    return result

# %%
# - [x] 프로그래머스 - 같은 숫자는 싫어 (Level 1)
# 중복 숫자 제거 
# 순서는 유지

# 이거 내가 만든거
# def solution(arr):
#     answer = []
#     # pop 쓰면 되겠다
#     for i in range(arr):
#         answer += i

#     result = set.answer.reverse.sorted().pop()

#     return result


# 수정되야할 부분
# range는 정수를 인자로 받는다
# 

def solution(arr):
    answer = []

    for num in arr:
        if not answer or answer [-1] != num:
            answer.append(num)

    return answer

# %% [markdown]
# 내장 함수 vs 메소드
# 내장 함수 (Built-in Functions)
#
# 파이썬에 기본적으로 포함되어 있는 독립적인 함수들입니다.
# 어떤 객체에도 속하지 않고 전역 네임스페이스에 존재합니다.
# 직접 호출이 가능합니다: function_name(arguments)
# 예: print(), len(), sorted(), sum(), range(), type()
#
# 메소드 (Methods)
#
# 특정 객체나 클래스에 속한 함수입니다.
# 항상 특정 객체의 컨텍스트 내에서 호출됩니다.
# 점(.) 표기법으로 호출합니다: object.method(arguments)
# 예: list.append(), string.upper(), dict.keys(), set.add()

# %% [markdown]
# 자주 사용되는 내장 함수 (Built-in Functions)
#
# print() - 콘솔에 출력
# len() - 객체의 길이 반환
# range() - 숫자 시퀀스 생성
# int(), str(), float() - 타입 변환
# input() - 사용자 입력 받기
# list(), dict(), set(), tuple() - 컬렉션 타입 생성
# sorted() - 정렬된 시퀀스 반환
# max(), min() - 최대값, 최소값 반환
# sum() - 합계 계산
# open() - 파일 열기
# zip() - 여러 이터러블 결합
# map() - 함수를 각 요소에 적용
# filter() - 조건에 맞는 요소 필터링
# enumerate() - 인덱스와 값 쌍 생성
# type() - 객체의 타입 확인
#
# 자주 사용되는 메소드 (Methods)
# 문자열(str) 메소드
#
# split() - 문자열 분할
# strip() - 공백 제거
# replace() - 문자열 치환
# lower(), upper() - 대소문자 변환
# join() - 문자열 결합
# format() - 문자열 포맷팅
# startswith(), endswith() - 시작/끝 문자열 확인
#
# 리스트(list) 메소드
#
# append() - 요소 추가
# pop() - 요소 제거 및 반환
# remove() - 값으로 요소 제거
# sort() - 리스트 정렬
# index() - 요소 인덱스 찾기
# extend() - 리스트에 이터러블 추가
# insert() - 특정 위치에 요소 삽입
#
# 딕셔너리(dict) 메소드
#
# get() - 키로 값 가져오기
# keys(), values(), items() - 키/값/쌍 반환
# update() - 딕셔너리 업데이트
# pop() - 키로 항목 제거 및 반환
#
# 세트(set) 메소드
#
# add() - 요소 추가
# remove() - 요소 제거
# union(), intersection() - 합집합, 교집합
#
# 파일 메소드
#
# read() - 파일 전체 읽기
# write() - 파일에 쓰기
# readline() - 한 줄 읽기
# close() - 파일 닫기

# %%
# - [x]백준 2980번 - 도로와 신호등 (Silver IV)

# n, l = int(input())
# for d, r, g in n:
    
def min_travel_time(N, L, signals):
    # 현재 위치와 시간
    current_pos = 0
    current_time = 0
    
    for signal in signals:
        D, R, G = signal
        # D 위치까지 이동하는 데 걸리는 시간
        travel_time = D - current_pos
        
        # 신호등 위치에 도착한 시간
        current_time += travel_time
        current_pos = D
        
        # 신호등의 현재 상태 계산
        cycle_time = R + G
        time_in_cycle = current_time % cycle_time
        
        # 신호등이 빨간색이면 기다려야 함
        if time_in_cycle < R:
            # 기다리는 시간 추가
            current_time += R - time_in_cycle
    
    # 마지막 신호등부터 도로 끝까지 이동
    current_time += L - current_pos
    
    return current_time

# 입력 처리
N, L = map(int, input().split())
signals = []
for _ in range(N):
    D, R, G = map(int, input().split())
    signals.append((D, R, G))

# 결과 출력
print(min_travel_time(N, L, signals))
# Out:
#   Cell In[3], line 6
#     for in n
#         ^
# SyntaxError: invalid syntax

# %%
# - [x] 프로그레머스 - 실패율

# n x n 크기의 정사각 격자 형태 
# m x m 크기 정사각 격자 형태
# 실패율 
# 실패율이 높은 스테이지부터 내림차순으로 스테이지의 번호가 담겨있는 배열를 리터
# n 전체 스테이지 개수
# stages 사용자가 현재 남아있는 스테이지
# result 싶패율이 높은 스테이지 부터 내림차순으로 스테이비 번호가 담겨있는 배열

# 실패율을 먼저 계산하고 -> 내림차순으로 정렬 -> 

def solution(N, stages):
    # 각 스테이지별 도전 중인 사용자 수를 계산
    fail_counts = [0] * (N + 2)  # 인덱스를 1부터 시작하기 위해 N+2 크기로 생성
    for stage in stages:
        fail_counts[stage] += 1
    
    # 실패율 계산을 위한 리스트 초기화
    failure_rates = []
    
    # 해당 스테이지에 도달한 플레이어 수
    remaining_players = len(stages)
    
    # 각 스테이지의 실패율 계산
    for i in range(1, N + 1):
        # 스테이지에 도달한 플레이어가 없는 경우, 실패율은 0
        if remaining_players == 0:
            failure_rates.append((i, 0))
        else:
            failure_rates.append((i, fail_counts[i] / remaining_players))
            remaining_players -= fail_counts[i]
    
    # 실패율에 따라 내림차순 정렬, 실패율이 같은 경우 스테이지 번호 오름차순
    # key 함수에서 -x[1]은 실패율을 내림차순으로 정렬하게 함
    failure_rates.sort(key=lambda x: (-x[1], x[0]))
    
    # 정렬된 스테이지 번호만 추출하여 반환
    return [stage for stage, _ in failure_rates]

# 예제 1 테스트
N1 = 5
stages1 = [2, 1, 2, 6, 2, 4, 3, 3]
print("예제 1 결과:", solution(N1, stages1))  # [3, 4, 2, 1, 5]

# 예제 2 테스트
N2 = 4
stages2 = [4, 4, 4, 4, 4]
print("예제 2 결과:", solution(N2, stages2))  # [4, 1, 2, 3]

# %% [markdown]
# 레벨 1 구현/시뮬레이션 문제:
#
# 숫자 문자열과 영단어 - 숫자를 영어 단어로 바꾼 문자열을 다시 숫자로 변환하는 구현 문제
# 키패드 누르기 - 주어진 규칙에 따라 키패드를 누르는 손가락을 결정하는 시뮬레이션 문제
# 크레인 인형뽑기 게임 - 격자 구조에서 특정 규칙에 따라 인형을 뽑는 시뮬레이션
# 신규 아이디 추천 - 주어진 규칙에 따라 아이디 문자열을 변환하는 구현 문제
# 실패율 - 게임 스테이지의 실패율을 계산하고 정렬하는 구현 문제
# 다트 게임 - 주어진 규칙에 따라 다트 게임 점수 계산하는 구현 문제
# 비밀지도 - 두 개의 이진수 배열을 합쳐 특정 패턴을 찾는 구현 문제
# [1차] 캐시 - LRU 캐시 알고리즘을 구현하는 문제
#
# 레벨 2 구현/시뮬레이션 문제:
#
# 문자열 압축 - 문자열 패턴을 찾아 압축하는 구현 문제
# 오픈채팅방 - 채팅방 출입 로그를 처리하는 구현 문제
# 주차 요금 계산 - 주차 시간에 따른 요금 계산 시뮬레이션
# [1차] 프렌즈4블록 - 블록 게임 시뮬레이션 문제
# [3차] n진수 게임 - n진법으로 숫자를 변환하는 게임 시뮬레이션
# [3차] 파일명 정렬 - 주어진 규칙에 따라 파일명을 정렬하는 구현 문제
# [1차] 뉴스 클러스터링 - 자카드 유사도를 구현하는 문제
# 행렬 테두리 회전하기 - 2차원 배열에서 테두리를 회전시키는 시뮬레이션
# 메뉴 리뉴얼 - 주문 데이터에서 조합을 찾는 구현 문제
# 거리두기 확인하기 - 2차원 격자에서 거리두기 규칙을 확인하는 시뮬레이션

# %%
# - [x] 프로그래머스 - 비밀지도 
def solution(n, arr1, arr2):
    answer = []
    for i in range(n):
        arr1[i] = format(arr1[i], 'b').zfill(n) # zfill n의 칸수많큼 0을 넣어준다 just()라는 메서드 도있음
        arr2[i] = format(arr2[i], "b").zfill(n)

        temp = ""
        for a, b in zip(arr1[i], arr2[i]):
            if a == "0" and b == "0":
                temp += " "
            if a == "1" or b == "1":
                temp += "#"
        answer.append(temp)            

    return answer

# %%
# 백준 뱀 3190번
# 사과의 위치와 뱀의 이동경로가 주어질 때 이 게임이 몇 초에 끝나는지 계산하라.
# board NxN
# 맨위 좌측에서 시작
# 뱀길이 1 
# 뱀 처음 오른쪽방향

# 매초마다 움직임
# 뱀은 몸길이를 늘려 머리를 다음칸에 위치
# 이동한 칸에 사과가 있다면 그칸에 있던사과가 없어지고 
from collections import deque

n = int(input()) # 보드 크기
k = int(input()) # 사과 개수

apples = [] # 사과의 위치

for _ in range(k):
    row, col = map(int, input().split()) # map int을 통해 문자열을 정수로 바꾸고 새로운 객체를 생성
    apples.append((row, col))

l = int(input()) # 뱀의 방향 전환 횟수

directions = [] # 방향

for _ in range(l):
    time, direction = input().split()
    directions.append((int(time), direction))

snake = deque([1, 1])


# 


# for apple_col, apple_row in range(k): # 1행 1 열에은 사과가 없다
#     apple_col, apple_row = list(input().split())

# 먼저 for 문을 담을 빈 리스트 생성

    
# for apple_col, apple_row in range(l): # 1행 1 열에은 사과가 없다
#     apple_col, apple_row = list(input().split())

# %%
n, k = map(int, input().split())

board = []
for _ in range(n):
    row = list(map(int, input().split())

# %%
min(compress(text, tok_len) for tok_len in list(range(1, int(len(text)/2) + 1)) + [len(text)])

min = ()
for tok_len in list(range(1, int(len(text)/2) + 1)) + [len(text)]
    min.append(compress(text, tok_len))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 min(compress(text, tok_len) for tok_len in list(range(1, int(len(text)/2) + 1)) + [len(text)])
#
# NameError: name 'text' is not defined

# %%
stack = []

# 원소 추가 (push)
stack.append(1)
stack.append(2)
stack.append(3)

# 원소 제거 (pop)
top_element = stack.pop()
# Out:
# [1, 2]

# %%
# 딕셔너리로 해시맵 구현
hash_map = {}

# 키-값 추가/수정
hash_map["apple"] = 5
hash_map["banana"] = 3
hash_map["apple"] = 7  # 기존 값 덮어쓰기

hash_map
# Out:
# {'apple': 7, 'banana': 3}
